# %%
from transformers import VitsModel, AutoTokenizer
import torch

model = VitsModel.from_pretrained("facebook/mms-tts-rus")
tokenizer = AutoTokenizer.from_pretrained("facebook/mms-tts-rus")

text = "Привет как дела?"
inputs = tokenizer(text, return_tensors="pt")

with torch.no_grad():
    output = model(**inputs).waveform

# %%
import scipy

scipy.io.wavfile.write("techno.wav", rate=model.config.sampling_rate, data=output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 import scipy
# ----> 3 scipy.io.wavfile.write("techno.wav", rate=model.config.sampling_rate, data=output)
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/scipy/io/wavfile.py:772, in write(filename, rate, data)
#     769 fs = rate
#     771 try:
# --> 772     dkind = data.dtype.kind
#     773     if not (dkind == 'i' or dkind == 'f' or (dkind == 'u' and
#     774                                              data.dtype.itemsize == 1)):
#     775         raise ValueError("Unsupported data type '%s'" % data.dtype)
#
# AttributeError: 'torch.dtype' object has no attribute 'kind'

# %%
from IPython.display import Audio

Audio(output, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pip install --upgrade git+https://github.com/huggingface/transformers.git accelerate datasets[audio]
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-v324p9fj
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-v324p9fj
#   Resolved https://github.com/huggingface/transformers.git to commit 00c1d87a7d5c8dfb4554370983b5a3f7c069edd7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (0.28.0)
# Collecting datasets[audio]
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: filelock in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (2023.10.3)
# Requirement already satisfied: requests in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (0.15.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (4.66.1)
# Requirement already satisfied: psutil in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from accelerate) (2.0.1)
# Collecting pyarrow>=12.0.0
#   Downloading pyarrow-15.0.1-cp311-cp311-manylinux_2_28_x86_64.whl (38.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 5.1 MB/s eta 0:00:00m eta 0:00:010:01:01m
# Collecting pyarrow-hotfix
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from datasets[audio]) (2.1.1)
# Collecting xxhash
#   Downloading xxhash-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 8.1 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from datasets[audio]) (2023.10.0)
# Requirement already satisfied: aiohttp in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from datasets[audio]) (3.8.6)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.9 MB/s eta 0:00:0010.1 MB/s eta 0:00:01
# Collecting librosa
#   Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 6.7 MB/s eta 0:00:007.5 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from aiohttp->datasets[audio]) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from aiohttp->datasets[audio]) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from aiohttp->datasets[audio]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from aiohttp->datasets[audio]) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from aiohttp->datasets[audio]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from aiohttp->datasets[audio]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from aiohttp->datasets[audio]) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from requests->transformers==4.39.0.dev0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from requests->transformers==4.39.0.dev0) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from requests->transformers==4.39.0.dev0) (2022.12.7)
# Requirement already satisfied: cffi>=1.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from soundfile>=0.12.1->datasets[audio]) (1.15.1)
# Requirement already satisfied: sympy in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: setuptools in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate) (66.1.1)
# Requirement already satisfied: wheel in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate) (0.41.2)
# Requirement already satisfied: cmake in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.5)
# Requirement already satisfied: lit in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: scipy>=1.2.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from librosa->datasets[audio]) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from librosa->datasets[audio]) (1.3.1)
# Requirement already satisfied: joblib>=0.14 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from librosa->datasets[audio]) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from librosa->datasets[audio]) (5.1.1)
# Collecting numba>=0.51.0
#   Downloading numba-0.59.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 10.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pooch>=1.0
#   Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 7.6 MB/s eta 0:00:00
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.2 MB/s eta 0:00:0031m12.2 MB/s eta 0:00:01
# Requirement already satisfied: lazy-loader>=0.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from librosa->datasets[audio]) (0.3)
# Collecting msgpack>=1.0
#   Downloading msgpack-1.0.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 9.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from pandas->datasets[audio]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from pandas->datasets[audio]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from pandas->datasets[audio]) (2023.3)
# Requirement already satisfied: pycparser in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]) (2.21)
# Collecting llvmlite<0.43,>=0.42.0dev0
#   Downloading llvmlite-0.42.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Requirement already satisfied: platformdirs>=2.5.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from pooch>=1.0->librosa->datasets[audio]) (3.10.0)
# Requirement already satisfied: six>=1.5 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets[audio]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa->datasets[audio]) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.39.0.dev0-py3-none-any.whl size=8714194 sha256=b92c83b3c944b43a142d84f1719c8f4620bce8bb81ad69214d33a7faf38dfbba
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a03heble/wheels/32/4b/78/f195c684dd3a9ed21f3b39fe8f85b48df7918581b6437be143
# Successfully built transformers
# Installing collected packages: xxhash, soxr, pyarrow-hotfix, pyarrow, msgpack, llvmlite, dill, audioread, soundfile, pooch, numba, multiprocess, librosa, transformers, datasets
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed audioread-3.0.1 datasets-2.18.0 dill-0.3.8 librosa-0.10.1 llvmlite-0.42.0 msgpack-1.0.8 multiprocess-0.70.16 numba-0.59.0 pooch-1.8.1 pyarrow-15.0.1 pyarrow-hotfix-0.6 soundfile-0.12.1 soxr-0.3.7 transformers-4.39.0.dev0 xxhash-3.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=30,
    batch_size=16,
    return_timestamps=True,
    torch_dtype=torch_dtype,
    device=device,
)

dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe(sample)
print(result["text"])
# Out:
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       7 torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32
#       9 model_id = "openai/whisper-large-v3"
# ---> 11 model = AutoModelForSpeechSeq2Seq.from_pretrained(
#      12     model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
#      13 )
#      14 model.to(device)
#      16 processor = AutoProcessor.from_pretrained(model_id)
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:561, in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     557         cls.register(config.__class__, model_class, exist_ok=True)
#     558     return model_class.from_pretrained(
#     559         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     560     )
# --> 561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
#     563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/transformers/modeling_utils.py:3164, in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3161     filename = pretrained_model_name_or_path
#    3162     resolved_archive_file = download_url(pretrained_model_name_or_path)
#    3163 else:
# -> 3164     # set correct filename
#    3165     if from_tf:
#    3166         filename = TF2_WEIGHTS_NAME
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/transformers/utils/hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     395 user_agent = http_user_agent(user_agent)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#     413     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/huggingface_hub/file_download.py:1492, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1489         if local_dir is not None:
#    1490             _check_disk_space(expected_size, local_dir)
# -> 1492     http_get(
#    1493         url_to_download,
#    1494         temp_file,
#    1495         proxies=proxies,
#    1496         resume_size=resume_size,
#    1497         headers=headers,
#    1498         expected_size=expected_size,
#    1499         displayed_filename=filename,
#    1500     )
#    1502 if local_dir is None:
#    1503     logger.debug(f"Storing {url} in cache at {blob_path}")
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/huggingface_hub/file_download.py:547, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries)
#     545 new_resume_size = resume_size
#     546 try:
# --> 547     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     548         if chunk:  # filter out keep-alive new chunks
#     549             progress.update(len(chunk))
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/urllib3/response.py:936, in HTTPResponse.stream(self, amt, decode_content)
#     934 else:
#     935     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 936         data = self.read(amt=amt, decode_content=decode_content)
#     938         if data:
#     939             yield data
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/urllib3/response.py:879, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     876     if len(self._decoded_buffer) >= amt:
#     877         return self._decoded_buffer.get(amt)
# --> 879 data = self._raw_read(amt)
#     881 flush_decoder = amt is None or (amt != 0 and not data)
#     883 if not data and len(self._decoded_buffer) == 0:
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/urllib3/response.py:814, in HTTPResponse._raw_read(self, amt)
#     811 fp_closed = getattr(self._fp, "closed", False)
#     813 with self._error_catcher():
# --> 814     data = self._fp_read(amt) if not fp_closed else b""
#     815     if amt is not None and amt != 0 and not data:
#     816         # Platform-specific: Buggy versions of Python.
#     817         # Close the connection when no data is returned
#    (...)
#     822         # not properly close the connection in all cases. There is
#     823         # no harm in redundantly calling close.
#     824         self._fp.close()
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/urllib3/response.py:799, in HTTPResponse._fp_read(self, amt)
#     796     return buffer.getvalue()
#     797 else:
#     798     # StringIO doesn't like amt=None
# --> 799     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /usr/lib/python3.11/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /usr/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /usr/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from transformers import pipeline
import scipy

synthesiser = pipeline("text-to-speech", "suno/bark-small")

speech = synthesiser("Hello, my dog is cooler than you!", forward_params={"do_sample": True})

scipy.io.wavfile.write("bark_out.wav", rate=speech["sampling_rate"], data=speech["audio"])
# Out:
# config.json:   0%|          | 0.00/8.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# generation_config.json:   0%|          | 0.00/4.91k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/353 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 8
#       4 synthesiser = pipeline("text-to-speech", "suno/bark-small")
#       6 speech = synthesiser("Hello, my dog is cooler than you!", forward_params={"do_sample": True})
# ----> 8 scipy.io.wavfile.write("bark_out.wav", rate=speech["sampling_rate"], data=speech["audio"])
#
# File ~/tech_park/ml/.env/lib/python3.11/site-packages/scipy/io/wavfile.py:797, in write(filename, rate, data)
#     794 bytes_per_second = fs*(bit_depth // 8)*channels
#     795 block_align = channels * (bit_depth // 8)
# --> 797 fmt_chunk_data = struct.pack('<HHIIHH', format_tag, channels, fs,
#     798                              bytes_per_second, block_align, bit_depth)
#     799 if not (dkind == 'i' or dkind == 'u'):
#     800     # add cbSize field for non-PCM files
#     801     fmt_chunk_data += b'\x00\x00'
#
# error: ushort format requires 0 <= number <= 65535

# %%
pip install git+https://github.com/huggingface/transformers.git
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-783almbm
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-783almbm
#   Resolved https://github.com/huggingface/transformers.git to commit 00c1d87a7d5c8dfb4554370983b5a3f7c069edd7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (2023.10.3)
# Requirement already satisfied: requests in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (0.15.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from transformers==4.39.0.dev0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from requests->transformers==4.39.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from requests->transformers==4.39.0.dev0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from requests->transformers==4.39.0.dev0) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vladimir/tech_park/ml/.env/lib/python3.11/site-packages (from requests->transformers==4.39.0.dev0) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoProcessor, AutoModel


processor = AutoProcessor.from_pretrained("suno/bark-small")
model = AutoModel.from_pretrained("suno/bark-small")

inputs = processor(
    text=["Привет как дела"],
    return_tensors="pt",
)

speech_values = model.generate(**inputs, do_sample=True)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.

# %%
from IPython.display import Audio

sampling_rate = model.generation_config.sample_rate
Audio(speech_values.cpu().numpy().squeeze(), rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from transformers import VitsModel, AutoTokenizer
import torch
import scipy

model = VitsModel.from_pretrained("joefox/tts_vits_ru_hf")
tokenizer = AutoTokenizer.from_pretrained("joefox/tts_vits_ru_hf")

text = "на русском с маленькой буквы"
text = text.lower()
inputs = tokenizer(text, return_tensors="pt")
inputs['speaker_id'] = 1

with torch.no_grad():
    output = model(**inputs).waveform

print(output)
scipy.io.wavfile.write("cat.wav", rate=model.config.sampling_rate, data=output[0].cpu().numpy())
# Out:
# tensor([[-5.6086e-05, -1.7287e-05, -8.6601e-06,  ..., -3.7106e-04,
#           1.5111e-04, -1.0670e-02]])

# %%
from IPython.display import Audio

Audio(output, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np

# Предположим, что 'output' представляет собой массив numpy с аудиоданными
output_int = np.int16(output[0].cpu().numpy() * 32767)  # От -32767 до 32767

# Преобразовать в байты
output_bytes = output_int.tostring()
# Out:
# /tmp/ipykernel_16583/3151741019.py:7: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   output_bytes = output_int.tostring()

# %%
output_bytes
# Out:
# b'\x ...
